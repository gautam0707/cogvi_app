# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *
# %matplotlib inline
import random
import math

# %%
def rand_circle(size):
    xs = []
    ys = []
    for _ in range(2000):
        # random angle
        alpha = 2 * math.pi * random.random()
        # random radius
        r = circle_r * math.sqrt(random.random())
        # calculating coordinates
        x = r * math.cos(alpha) + circle_x
        y = r * math.sin(alpha) + circle_y
        xs.append(x)
        ys.append(y)
    return xs, ys

# %%
# radius of the circle
circle_r = 1
# center of the circle (x, y)
circle_x = 0
circle_y = 0
xs, ys = rand_circle(2000)

# %%
def rays(color, num_of_rays,ray_width, x_range, y_range, center):
    srcs = [[random.uniform(x_range[0],x_range[1]), random.uniform(y_range[0],y_range[1])] for _ in range(num_of_rays)]
    for i in srcs:
        plt.plot([center[0],i[0]], [center[1], i[1]],color=color,linewidth=ray_width)

# %%
def run_different_tests(num_rays, ray_width)

# %%
#plt.plot(xs, ys, color='gray', linewidth=0.1)
center = [0.5,0.5]
num_rays = 500
ray_width = 0.01
rays('red', num_rays, ray_width, [0,0.15],[0,0.15],center)
rays('orange', num_rays, ray_width, [0.3,0.45],[0,0.15],center)
rays('gray', num_rays, ray_width, [0.6,0.75],[0,0.15],center)
rays('green', num_rays, ray_width, [0.9,1.5],[0,0.15],center)
rays('blue', num_rays, ray_width, [0.9,1.5],[0.3,0.45],center)
rays('indigo', num_rays, ray_width, [0.9,1.5],[0.6,0.75],center)
rays('violet', num_rays, ray_width, [0.9,1.5],[0.9,1.5],center)
rays('brown', num_rays, ray_width, [0.6,0.75],[0.9,1.5],center)
rays('magenta', num_rays, ray_width, [0.3,0.45],[0.9,1.5],center)
rays('cyan', num_rays, ray_width, [0,0.15],[0.9,1.5],center)
rays('purple', num_rays, ray_width, [0,0.15],[0.3,0.45],center)
rays('black', num_rays, ray_width, [0,0.15],[0.6,0.75],center)

plt.axis('off')
plt.savefig('logo.png',dpi = 250)

# %%
#plt.plot(xs, ys, color='gray', linewidth=0.1)
center = [0.4,0.4]
num_rays = 500
ray_width = 0.01
rays('red', num_rays, ray_width, [0,0.2],[0,0.2],center)
rays('orange', num_rays, ray_width, [0.2,0.4],[0,0.2],center)
rays('gray', num_rays, ray_width, [0.4,0.7],[0,0.2],center)
rays('violet', num_rays, ray_width, [0.7,1.5],[0,0.2],center)
rays('blue', num_rays, ray_width, [0.8,1.5],[0.2,0.5],center)
rays('indigo', num_rays, ray_width, [0.8,1.5],[0.5,0.8],center)
rays('green', num_rays, ray_width, [0.8,1.5],[0.8,1.5],center)
rays('brown', num_rays, ray_width, [0.6,0.8],[0.8,1.5],center)
rays('magenta', num_rays, ray_width, [0.3,0.6],[0.8,1.5],center)
rays('cyan', num_rays, ray_width, [0,0.3],[0.8,1.5],center)
rays('purple', num_rays, ray_width, [0,0.2],[0.2,0.5],center)
rays('black', num_rays, ray_width, [0,0.2],[0.5,0.8],center)

plt.axis('off')
plt.savefig('logo1.png',dpi = 500)
